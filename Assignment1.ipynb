# %% [markdown]
# <a href="https://colab.research.google.com/github/paladugulashruthi/NNDL/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sp
curr_x=np.random.randint(1,5)
print("\n The value of x generated randomly is ",curr_x)
learning_rate=0.01
max_iter=50
iter_count=0

x=sp.Symbol('x')
equ=x**4+3*x**2+10
expr=sp.diff(equ,x)
print("expression is ",expr)

df=lambda x:4*x**3+6*x

while  iter_count < max_iter :
  prev_x=curr_x
  delta_x=-(learning_rate)*df(prev_x)
  curr_x=curr_x+delta_x
  iter_count=iter_count+1
  print("Iteration",iter_count)
  print("X value is{:.2f} ".format(curr_x))
  #print("xvalue is ",curr_x)
print("The local minimum occurs at {:.2f} ".format(curr_x))
expr3=expr.subs(x,curr_x)
print(expr3)
# Out:
#  The value of x generated randomly is  1
# expression is  4*x**3 + 6*x
# Iteration 1
# X value is0.90
# Iteration 2
# X value is0.82
# Iteration 3
# X value is0.75
# Iteration 4
# X value is0.68
# Iteration 5
# X value is0.63
# Iteration 6
# X value is0.58
# Iteration 7
# X value is0.54
# Iteration 8
# X value is0.50
# Iteration 9
# X value is0.47
# Iteration 10
# X value is0.43
# Iteration 11
# X value is0.40
# Iteration 12
# X value is0.38
# Iteration 13
# X value is0.35
# Iteration 14
# X value is0.33
# Iteration 15
# X value is0.31
# Iteration 16
# X value is0.29
# Iteration 17
# X value is0.27
# Iteration 18
# X value is0.25
# Iteration 19
# X value is0.24
# Iteration 20
# X value is0.22
# Iteration 21
# X value is0.21
# Iteration 22
# X value is0.20
# Iteration 23
# X value is0.18
# Iteration 24
# X value is0.17
# Iteration 25
# X value is0.16
# Iteration 26
# X value is0.15
# Iteration 27
# X value is0.14
# Iteration 28
# X value is0.13
# Iteration 29
# X value is0.13
# Iteration 30
# X value is0.12
# Iteration 31
# X value is0.11
# Iteration 32
# X value is0.10
# Iteration 33
# X value is0.10
# Iteration 34
# X value is0.09
# Iteration 35
# X value is0.09
# Iteration 36
# X value is0.08
# Iteration 37
# X value is0.08
# Iteration 38
# X value is0.07
# Iteration 39
# X value is0.07
# Iteration 40
# X value is0.06
# Iteration 41
# X value is0.06
# Iteration 42
# X value is0.06
# Iteration 43
# X value is0.05
# Iteration 44
# X value is0.05
# Iteration 45
# X value is0.05
# Iteration 46
# X value is0.04
# Iteration 47
# X value is0.04
# Iteration 48
# X value is0.04
# Iteration 49
# X value is0.04
# Iteration 50
# X value is0.03
# The local minimum occurs at 0.03
# 0.205693694960735
